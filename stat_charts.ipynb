# %%
import matplotlib.pyplot as plt

# %%
eps = []
q_table_lengths = []
avg_diamonds_mined = []
diamonds_mined = []

with open("results.txt", "r") as f:
    stats = f.readlines()

for i in stats:
    i = i.split(',')
    # print(i)
    eps.append(int(i[0]))
    q_table_lengths.append(float(i[1]))
    avg_diamonds_mined.append(float(i[2]))

# print(q_table_lengths)
# print(len(eps))

# plt.xlim(0, eps[-1])
# plt.plot(eps[::10], q_table_lengths[::10], 'o')
# plt.show()

plt.scatter(eps[::4], avg_diamonds_mined[::4])
